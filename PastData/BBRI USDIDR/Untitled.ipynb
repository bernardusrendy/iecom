# %%
import pandas as pd
from pandas import DataFrame as df
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# %%
data1=pd.read_excel('./BBRI.xlsx')
data2=pd.read_excel('./USDIDR.xlsx')

# %%
close1=np.array(data1['close'])
close2=np.array(data2['close'])

# %%
plt.plot(signal.correlate(close1-3720,close2-13935)[300:601])

# %%
np.where(signal.correlate(close1-3720,close2-13935)[300:601]==signal.correlate(close1-3720,close2-13935)[300:601].max())
# Out:
# (array([43], dtype=int64),)

# %%
signal.correlate(close1-3720,close2-13935)[300:601][43]
# Out:
# 27549800

# %%
a=close1-3720
b=close2-13935
a = (a - np.mean(a)) / (np.std(a) * len(a))
b = (b - np.mean(b)) / (np.std(b))
c = np.correlate(b, a, 'full')

# %%
c.min()
# Out:
# -0.7531170076193596

# %%
plt.plot(c)

# %%
plt.plot(signal.correlate(close1-3720,close1-3720)[300:601])
